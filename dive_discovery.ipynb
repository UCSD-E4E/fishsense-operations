# %%
from pathlib import Path

import pandas as pd
from tqdm.auto import tqdm

from backend import get_dive_checksum, get_dive_date

# %%
data_root = Path('//e4e-nas.ucsd.edu/fishsense_data/REEF/data')

# %%
df = pd.DataFrame()

# %%
images = data_root.rglob('*.ORF', case_sensitive=False)

# %%
dives = {img.parent.absolute() for img in images}

# %%
df['directory'] = [dive.as_posix() for dive in dives]

# %%
df['date'] = None
df['invalid_image'] = None
df['multiple_date'] = None
df['checksum'] = None

# %%
for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
    path = Path(row['directory'])
    mean_date, invalid_dates, multiple_dates = get_dive_date(path)
    dive_checksum = get_dive_checksum(path)
    df.at[idx, 'date'] = mean_date
    df.at[idx, 'invalid_image'] = invalid_dates
    df.at[idx, 'multiple_date'] = multiple_dates
# Out:
#   0%|          | 0/502 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       2 path = Path(row['directory'])
#       3 mean_date, invalid_dates, multiple_dates = get_dive_date(path)
# ----> 4 dive_checksum = get_dive_checksum(path)
#       5 df.at[idx, 'date'] = mean_date
#       6 df.at[idx, 'invalid_image'] = invalid_dates
#
# File d:\workspace\e4e\fishsense\fishsense-operations\backend.py:47, in get_dive_checksum(path)
#      45 reference_data = sorted(path.rglob('*.orf', case_sensitive=False))
#      46 with multiprocessing.Pool() as pool:
# ---> 47     checksums = pool.map(get_file_checksum, reference_data)
#      48 cksum = md5()
#      49 for idx, file in enumerate(reference_data):
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\multiprocessing\pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\multiprocessing\pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\multiprocessing\pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
df.to_csv('dives.csv')
# Out:
#                                              directory        date  \
# 0    //e4e-nas.ucsd.edu/fishsense_data/REEF/data/20...  2023-10-19
# 1    //e4e-nas.ucsd.edu/fishsense_data/REEF/data/20...  2023-08-31
# 2    //e4e-nas.ucsd.edu/fishsense_data/REEF/data/dr...  2023-10-18
# 3    //e4e-nas.ucsd.edu/fishsense_data/REEF/data/20...  2023-09-26
# 4    //e4e-nas.ucsd.edu/fishsense_data/REEF/data/20...  2023-08-29
# ..                                                 ...         ...
# 497  //e4e-nas.ucsd.edu/fishsense_data/REEF/data/dr...         NaN
# 498  //e4e-nas.ucsd.edu/fishsense_data/REEF/data/20...         NaN
# 499  //e4e-nas.ucsd.edu/fishsense_data/REEF/data/20...         NaN
# 500  //e4e-nas.ucsd.edu/fishsense_data/REEF/data/20...         NaN
# 501  //e4e-nas.ucsd.edu/fishsense_data/REEF/data/20...         NaN
#
#     invalid_image multiple_date
# 0           False         False
# 1           False         False
# 2           False          True
# 3            True         False
# 4           False         False
# ..            ...           ...
# 497           NaN           NaN
# 498           NaN           NaN
# 499           NaN           NaN
# 500           NaN           NaN
# 501           NaN           NaN
#
# [502 rows x 4 columns]
